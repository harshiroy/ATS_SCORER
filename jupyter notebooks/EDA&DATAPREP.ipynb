# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize']=(12,6)
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df=pd.read_csv('/content/resumeJD_pairs.csv',engine='python',on_bad_lines='skip')
print(f"Data Loaded Successfully:{df.shape[0]:,}rows,{df.shape[1]} columns")
print(f"\nColumns:{list(df.columns)}")
# Out:
# Data Loaded Successfully:9,544rows,35 columns
#
# Columns:['address', 'career_objective', 'skills', 'educational_institution_name', 'degree_names', 'passing_years', 'educational_results', 'result_types', 'major_field_of_studies', 'professional_company_names', 'company_urls', 'start_dates', 'end_dates', 'related_skils_in_job', 'positions', 'locations', 'responsibilities', 'extra_curricular_activity_types', 'extra_curricular_organization_names', 'extra_curricular_organization_links', 'role_positions', 'languages', 'proficiency_levels', 'certification_providers', 'certification_skills', 'online_links', 'issue_dates', 'expiry_dates', '\ufeffjob_position_name', 'educationaL_requirements', 'experiencere_requirement', 'age_requirement', 'responsibilities.1', 'skills_required', 'matched_score']

# %%
print("First 5 rows:")
df.head()
# Out:
# First 5 rows:
#   address                                   career_objective  \
# 0     NaN  Big data analytics working and database wareho...
# 1     NaN  Fresher looking to join as a data analyst and ...
# 2     NaN                                                NaN
# 3     NaN  To obtain a position in a fast-paced business ...
# 4     NaN  Professional accountant with an outstanding wo...
#
#                                               skills  \
# 0  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1  ['Data Analysis', 'Data Analytics', 'Business ...
# 2  ['Software Development', 'Machine Learning', '...
# 3  ['accounts payables', 'accounts receivables', ...
# 4  ['Analytical reasoning', 'Compliance testing k...
#
#                         educational_institution_name  \
# 0  ['The Amity School of Engineering & Technology...
# 1  ['Delhi University - Hansraj College', 'Delhi ...
# 2    ['Birla Institute of Technology (BIT), Ranchi']
# ...

# %%
print("Dataset Info:")
print("="*60)
df.info()
# Out:
# Dataset Info:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   address                              784 non-null    object
#  1   career_objective                     4740 non-null   object
#  2   skills                               9488 non-null   object
#  3   educational_institution_name         9460 non-null   object
#  4   degree_names                         9460 non-null   object
#  5   passing_years                        9460 non-null   object
#  6   educational_results                  9460 non-null   object
#  7   result_types                         9460 non-null   object
#  8   major_field_of_studies               9460 non-null   object
#  9   professional_company_names           9460 non-null   object
#  10  company_urls                         9460 non-null   object
# ...

# %%
print("\nStatistically Summary:")
df.describe()
# Out:
# Statistically Summary:
#        matched_score
# count    9544.000000
# mean        0.660831
# std         0.167040
# min         0.000000
# 25%         0.583333
# 50%         0.683333
# 75%         0.793333
# max         0.970000

# %%
print("]nText Columns Summary:")
df.describe(include='object')
# Out:
# ]nText Columns Summary:
#               address                                   career_objective  \
# count             784                                               4740
# unique             28                                                171
# top     Sunnyvale, CA  Big data analytics working and database wareho...
# freq               28                                                 28
#
#                                                    skills  \
# count                                                9488
# unique                                                340
# top     ['Python', 'MySQL', 'Tensorflow', 'Keras', 'Ma...
# freq                                                   56
#
#                              educational_institution_name degree_names  \
# count                                                9460         9460
# unique                                                328          180
# ...

# %%
print("Missing Values Analysis:")
print("="*60)
missing=df.isnull().sum()
missing_pct=(missing/len(df))*100
missing_df=pd.DataFrame({
    'Missing_Count':missing,
    'Percentage':missing_pct
})
print(missing_df)
print(f"\nTotal missing values:{missing.sum()}")
# Out:
# Missing Values Analysis:
# ...
#                                      Missing_Count  Percentage
# address                                       8760   91.785415
# career_objective                              4804   50.335289
# skills                                          56    0.586756
# educational_institution_name                    84    0.880134
# degree_names                                    84    0.880134
# passing_years                                   84    0.880134
# educational_results                             84    0.880134
# result_types                                    84    0.880134
# major_field_of_studies                          84    0.880134
# professional_company_names                      84    0.880134
# company_urls                                    84    0.880134
# start_dates                                     84    0.880134
# end_dates                                       84    0.880134
# ...

# %%
full_dupes=df.duplicated().sum()
print(f"Full duplicate rows:{full_dupes}")
# Out:
# Full duplicate rows:0

# %%
pair_dupes=df.duplicated(subset=['responsibilities','responsibilities.1']).sum()
print(f"Pair duplicate rows:{pair_dupes}")
# Out:
# Pair duplicate rows:9516

# %%
pair_dupes=df.duplicated(subset=['responsibilities','responsibilities.1']).sum()
print(f"Duplicate resume+JD pairs:{pair_dupes}")
# Out:
# Duplicate resume+JD pairs:9516

# %%
print("\nDuplicate rows:")
df[df.duplicated(subset=['responsibilities','responsibilities.1'],keep=False)]
# Out:
# Duplicate rows:
#      address                                   career_objective  \
# 0        NaN  Big data analytics working and database wareho...
# 1        NaN  Fresher looking to join as a data analyst and ...
# 2        NaN                                                NaN
# 3        NaN  To obtain a position in a fast-paced business ...
# 4        NaN  Professional accountant with an outstanding wo...
# ...      ...                                                ...
# 9539     NaN                                                NaN
# 9540     NaN  Expertise EDA modeler. I like to learn what my...
# 9541     NaN  Looking for roles related to application devel...
# 9542     NaN                                                NaN
# 9543     NaN                                                NaN
#
#                                                  skills  \
# 0     ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1     ['Data Analysis', 'Data Analytics', 'Business ...
# ...

# %%
print(f"Total rows:          {len(df)}")
print(f"Unique resumes:      {df['responsibilities'].nunique()}")
print(f"Unique JDs:          {df['responsibilities.1'].nunique()}")
print(f"Unique resume+JD pairs: {df[['responsibilities','responsibilities.1']].drop_duplicates().shape[0]}")
# Out:
# Total rows:          9544
# Unique resumes:      28
# Unique JDs:          28
# Unique resume+JD pairs: 28

# %%
bins = [0, 0.5, 0.75, 1.0]
labels = ['Low Match', 'Medium Match', 'High Match']
df['match_label'] = pd.cut(df['matched_score'], bins=bins, labels=labels, right=True, include_lowest=True)

print("Unique labels found:")
print(df['match_label'].value_counts())

# Is the casing consistent?
print(f"\nExpected 3 labels, got: {df['match_label'].nunique()} unique values")
print("Distinct values:", df['match_label'].unique())
# Out:
# Unique labels found:
# match_label
# Medium Match    4530
# High Match      3206
# Low Match       1808
# Name: count, dtype: int64
#
# Expected 3 labels, got: 3 unique values
# Distinct values: ['High Match', 'Medium Match', 'Low Match']
# Categories (3, object): ['Low Match' < 'Medium Match' < 'High Match']

# %%
print("Score distribution:")
print(df['matched_score'].describe())
print()

# Scores must be between 0.0 and 1.0 — flag the bad ones
invalid_scores = df[(df['matched_score'] < 0) | (df['matched_score'] > 1)]
print(f"Invalid scores (out of 0–1 range): {len(invalid_scores)}")
print(invalid_scores[['match_label', 'matched_score']])
# Out:
# Score distribution:
# count    9544.000000
# mean        0.660831
# std         0.167040
# min         0.000000
# 25%         0.583333
# 50%         0.683333
# 75%         0.793333
# max         0.970000
# Name: matched_score, dtype: float64
#
# Invalid scores (out of 0–1 range): 0
# Empty DataFrame
# Columns: [match_label, matched_score]
# Index: []

# %%
print("Score stats per label (after lowercasing):")
df['match_label_lower'] = df['match_label'].str.lower()
print(df.groupby('match_label_lower')['matched_score'].describe().round(2))
# Out:
# Score stats per label (after lowercasing):
#                     count  mean   std   min   25%   50%   75%   max
# match_label_lower
# high match         3206.0  0.83  0.03  0.75  0.79  0.85  0.85  0.97
# low match          1808.0  0.37  0.07  0.00  0.35  0.35  0.45  0.50
# medium match       4530.0  0.66  0.06  0.50  0.63  0.65  0.72  0.75

# %%
print("Missing values per column:")
print(df.isnull().sum())
print()

# Show the rows with nulls
nulls = df[df.isnull().any(axis=1)]
print(f"Rows with at least one null: {len(nulls)}")
nulls[['match_label', 'matched_score']].head(10)
# Out:
# Missing values per column:
# address                                8760
# career_objective                       4804
# skills                                   56
# educational_institution_name             84
# degree_names                             84
# passing_years                            84
# educational_results                      84
# result_types                             84
# major_field_of_studies                   84
# professional_company_names               84
# company_urls                             84
# start_dates                              84
# end_dates                                84
# related_skils_in_job                     84
# positions                                84
# locations                                84
# responsibilities                          0
# extra_curricular_activity_types        6118
# extra_curricular_organization_names    6118
# extra_curricular_organization_links    6118
# role_positions                         6118
# ...

# %%
print("=" * 50)
print("DATA QUALITY REPORT — merged_dataset.csv")
print("=" * 50)
print(f"  Total rows:             {len(df)}")
print(f"  Full duplicates:        {df.duplicated().sum()}")
print(f"  Duplicate pairs:        {df.duplicated(subset=['responsibilities','responsibilities.1']).sum()}")
print(f"  Null resume_text:       {df['responsibilities'].isnull().sum()}")
print(f"  Null job_description:   {df['responsibilities.1'].isnull().sum()}")
print(f"  Label case variants:    {df['match_label'].nunique()} (expected 3)")
print(f"  Invalid scores (<0/>1): {((df['matched_score'] < 0) | (df['matched_score'] > 1)).sum()}")
print("=" * 50)
# Out:
# ...
# DATA QUALITY REPORT — merged_dataset.csv
# ...
#   Total rows:             9544
#   Full duplicates:        0
#   Duplicate pairs:        9516
#   Null resume_text:       0
#   Null job_description:   0
#   Label case variants:    3 (expected 3)
#   Invalid scores (<0/>1): 0
# ...

# %%
# Pie chart + bar side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

counts = df['match_label'].str.lower().value_counts()

axes[0].bar(counts.index, counts.values, color=['green','orange','red'])
axes[0].set_title('Label Distribution (Bar)')
axes[0].set_ylabel('Count')

axes[1].pie(counts.values, labels=counts.index, autopct='%1.1f%%',
            colors=['green','orange','red'])
axes[1].set_title('Label Distribution (Pie)')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Before cleaning
axes[0].hist(df['matched_score'], bins=40, color='salmon', edgecolor='black')
axes[0].set_title('Score Distribution (Raw — with dirty data)')
axes[0].set_xlabel('matched_score')
axes[0].axvline(1.0, color='red', linestyle='--', label='Max valid = 1.0')
axes[0].legend()

# After cleaning
clean = df[(df['matched_score'] >= 0) & (df['matched_score'] <= 1)]
axes[1].hist(clean['matched_score'], bins=40, color='steelblue', edgecolor='black')
axes[1].set_title('Score Distribution (Cleaned)')
axes[1].set_xlabel('matched_score')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

df_plot = df.copy()
df_plot['match_label'] = df_plot['match_label'].str.lower()
df_plot = df_plot[(df_plot['matched_score'] >= 0) & (df_plot['matched_score'] <= 1)]

plt.figure(figsize=(10, 6))
sns.violinplot(data=df_plot, x='match_label', y='matched_score',
               order=['low match','medium match','high match'],
               palette=['red','orange','green'])
plt.title('Score Distribution per Label')
plt.xlabel('Match Label')
plt.ylabel('Match Score')
plt.show()

# %%
df_plot['resume_len'] = df_plot['responsibilities'].str.split().str.len()
df_plot['jd_len']     = df_plot['responsibilities.1'].str.split().str.len()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df_plot['resume_len'], bins=30, color='steelblue', edgecolor='black')
axes[0].set_title('Resume Word Count Distribution')
axes[0].set_xlabel('Words')

axes[1].hist(df_plot['jd_len'], bins=30, color='coral', edgecolor='black')
axes[1].set_title('Job Description Word Count Distribution')
axes[1].set_xlabel('Words')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(df_plot['resume_len'], df_plot['matched_score'], alpha=0.5, color='steelblue')
axes[0].set_xlabel('Resume Word Count')
axes[0].set_ylabel('Match Score')
axes[0].set_title('Resume Length vs Match Score')

axes[1].scatter(df_plot['jd_len'], df_plot['matched_score'], alpha=0.5, color='coral')
axes[1].set_xlabel('JD Word Count')
axes[1].set_ylabel('Match Score')
axes[1].set_title('JD Length vs Match Score')

plt.tight_layout()
plt.show()

# Actual correlation values
print("Resume length correlation:", df_plot['resume_len'].corr(df_plot['matched_score']).round(3))
print("JD length correlation:    ", df_plot['jd_len'].corr(df_plot['matched_score']).round(3))
# Out:
# Resume length correlation: 0.308
# JD length correlation:     0.308

# %%
plt.figure(figsize=(7, 5))
corr = df_plot[['resume_len', 'jd_len', 'matched_score']].corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
labels  = ['low match', 'medium match', 'high match'] # Corrected labels
colors  = ['Reds', 'Oranges', 'Greens']

for ax, label, cmap in zip(axes, labels, colors):
    text = ' '.join(df_plot[df_plot['match_label'] == label]['responsibilities'].dropna())
    wc = WordCloud(width=500, height=300, background_color='white',
                   colormap=cmap, max_words=80).generate(text)
    ax.imshow(wc, interpolation='bilinear')
    ax.axis('off')
    ax.set_title(f'{label.upper()} resumes', fontsize=14, fontweight='bold')

plt.suptitle('Most Common Words by Match Label', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Always record the starting point so that you  can see what changed
print("BEFORE CLEANING")
print("=" * 40)
print(f"Total rows:       {len(df)}")
print(f"Null resume_text: {df['responsibilities'].isnull().sum()}")
print(f"Null job_desc:    {df['responsibilities.1'].isnull().sum()}")
print(f"Duplicates:       {df.duplicated().sum()}")
print(f"Label variants:   {df['match_label'].nunique()}")
print(f"Invalid scores:   {((df['matched_score'] < 0) | (df['matched_score'] > 1)).sum()}")

df_clean = df.copy()
# Out:
# BEFORE CLEANING
# ...
# Total rows:       9544
# Null resume_text: 0
# Null job_desc:    0
# Duplicates:       0
# Label variants:   3
# Invalid scores:   0

# %%
print("Before:", df_clean['match_label'].value_counts().to_dict())

df_clean['match_label'] = df_clean['match_label'].str.lower().str.strip()

print("After: ", df_clean['match_label'].value_counts().to_dict())
print(f"\nUnique labels now: {df_clean['match_label'].nunique()} (expected 3)")
# Out:
# Before: {'Medium Match': 4530, 'High Match': 3206, 'Low Match': 1808}
# After:  {'medium match': 4530, 'high match': 3206, 'low match': 1808}
#
# Unique labels now: 3 (expected 3)

# %%
print(f"Before dropping nulls: {len(df_clean)} rows")

df_clean = df_clean.dropna(subset=['responsibilities', 'responsibilities.1'])

print(f"After dropping nulls:  {len(df_clean)} rows")
print(f"Removed: {len(df) - len(df_clean)} rows")
# Out:
# Before dropping nulls: 9544 rows
# After dropping nulls:  9544 rows
# Removed: 0 rows

# %%
print(f"Before removing duplicates: {len(df_clean)} rows")
print(f"Duplicate pairs found: {df_clean.duplicated(subset=['responsibilities','responsibilities.1']).sum()}")

df_clean = df_clean.drop_duplicates(subset=['responsibilities', 'responsibilities.1'], keep='first')

print(f"After removing duplicates:  {len(df_clean)} rows")
# Out:
# Before removing duplicates: 9544 rows
# Duplicate pairs found: 9516
# After removing duplicates:  28 rows

# %%
# Scores must be in [0.0, 1.0], anything else is a data error
invalid_mask = (df_clean['matched_score'] < 0.0) | (df_clean['matched_score'] > 1.0)
print(f"Invalid scores found: {invalid_mask.sum()}")
print(df_clean[invalid_mask][['match_label','matched_score']])

df_clean = df_clean[~invalid_mask]
print(f"\nRows after removing invalid scores: {len(df_clean)}")
# Out:
# Invalid scores found: 0
# Empty DataFrame
# Columns: [match_label, matched_score]
# Index: []
#
# Rows after removing invalid scores: 28

# %%
print("Score range per label:")
print(df_clean.groupby('match_label')['matched_score'].agg(['min','max','mean']).round(2))

# Flag any rows where label and score contradict each other
def label_score_mismatch(row):
    score = row['matched_score']
    label = row['match_label']
    if label == 'high'   and score < 0.70: return True
    if label == 'medium' and (score < 0.35 or score > 0.75): return True
    if label == 'low'    and score > 0.40: return True
    return False

mismatches = df_clean.apply(label_score_mismatch, axis=1)
print(f"\nLabel-score mismatches: {mismatches.sum()}")
df_clean[mismatches][['match_label','matched_score']]
# Out:
# Score range per label:
#                min   max  mean
# match_label
# high match    0.76  0.85  0.84
# low match     0.27  0.42  0.35
# medium match  0.55  0.75  0.65
#
# Label-score mismatches: 0
# Empty DataFrame
# Columns: [match_label, matched_score]
# Index: []

# %%
df_clean['resume_len'] = df_clean['responsibilities'].str.split().str.len()
df_clean['jd_len']     = df_clean['responsibilities.1'].str.split().str.len()

print("Short texts found:")
print(f"  resume_text < 20 words: {(df_clean['resume_len'] < 20).sum()}")
print(f"  job_description < 10 words: {(df_clean['jd_len'] < 10).sum()}")

df_clean = df_clean[(df_clean['resume_len'] >= 20) & (df_clean['jd_len'] >= 10)]
print(f"\nRows after removing short texts: {len(df_clean)}")
# Out:
# Short texts found:
#   resume_text < 20 words: 9
#   job_description < 10 words: 2
#
# Rows after removing short texts: 19

# %%
df_clean = df_clean.reset_index(drop=True)

print("=" * 45)
print("CLEANING SUMMARY")
print("=" * 45)
print(f"  Original rows:        {len(df)}")
print(f"  Final rows:           {len(df_clean)}")
print(f"  Rows removed:         {len(df) - len(df_clean)}")
print()
print(f"  Nulls remaining:      {df_clean.isnull().sum().sum()}")
print(f"  Duplicates remaining: {df_clean.duplicated().sum()}")
print(f"  Label variants:       {df_clean['match_label'].nunique()}")
print(f"  Score range:          {df_clean['matched_score'].min()} – {df_clean['matched_score'].max()}")
print()
print("Label distribution after cleaning:")
print(df_clean['match_label'].value_counts())
print("=" * 45)
# Out:
# ...
# CLEANING SUMMARY
# ...
#   Original rows:        9544
#   Final rows:           19
#   Rows removed:         9525
#
#   Nulls remaining:      184
#   Duplicates remaining: 0
#   Label variants:       3
#   Score range:          0.266666667 – 0.85
#
# Label distribution after cleaning:
# match_label
# medium match    8
# high match      8
# low match       3
# Name: count, dtype: int64
# ...

# %%
import os

output_dir = 'dataset'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

df_clean.to_csv(os.path.join(output_dir, 'cleaned_resumeJD_pairs.csv'), index=False)
print(f"Saved: {os.path.join(output_dir, 'cleaned_resumeJD_pairs.csv')} ({len(df_clean)} rows)")
# Out:
# Saved: dataset/cleaned_resumeJD_pairs.csv (19 rows)
